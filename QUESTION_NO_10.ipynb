# %% [markdown]
# # REMOVE DUPLICATE ELEMENTS FROM A LIST

# %%
from typing import List,Any
def remove_duplicate(data: List[Any]) -> List[Any]:
    if not isinstance(data,list):
        raise TypeError("Input must be a list.")
    if len(data) == 0:
        raise ValueError ("list must not be empty.")
    if len(data) == 1:
        print("list only has one element , required two or more.")
        return data
    result = []
    for i in data:
        if i not in result:
            result.append(i)
    return result

if __name__ == "__main__":
    numbers_list = [100,2,3,4,5,5,67,7,55,55,4]
    try:
        result = remove_duplicate(numbers_list)
        print(result)
    except (TypeError,ValueError) as e:
        print(e)
    except Exception as e:
        print(e)
# Out:
# [100, 2, 3, 4, 5, 67, 7, 55]
