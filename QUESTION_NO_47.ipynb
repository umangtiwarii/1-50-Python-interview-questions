# %% [markdown]
# # Find First Non-Repeating Character in Python String

# %%
def first_non_repeated_char(text:str)-> str:
    char_count = {}
    for char in text:
        if char in char_count:
            char_count[char] += 1
        else:
            char_count[char] = 1
    print(char_count)
    for char in text:
        if char_count[char] == 1:
            return char
if __name__ == "__main":
    try:
        text = "hheeloo"
        print(first_non_repeated_char(text))
    except Exception as e:
         print(e)

# %%
first_non_repeated_char("hhneello")
# Out:
# {'h': 2, 'n': 1, 'e': 2, 'l': 2, 'o': 1}
# 'n'

# %%
def first_non_repeated_char(text: str) -> str:
    if not isinstance(text, str):
        raise TypeError("Input must be a string")

    char_count = {}

    # Count occurrences of each character
    for char in text:
        if char in char_count:
            char_count[char] += 1
        else:
            char_count[char] = 1

    print(char_count)

    # Find first non-repeated character
    for char in text:
        if char_count[char] == 1:
            return char

    # If no non-repeated character exists
    raise ValueError("No non-repeated character found")


if __name__ == "__main__":
    try:
        text = input("Enter your text: ")
        result = first_non_repeated_char(text)
        print("First non-repeated character is:", result)

    except TypeError as e:
        print(e)

    except ValueError as e:
        print(e)

    except Exception as e:
        print(e)
# Out:
# Enter your text:  uumang
# {'u': 2, 'm': 1, 'a': 1, 'n': 1, 'g': 1}
# First non-repeated character is: m
