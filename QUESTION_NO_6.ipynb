# %% [markdown]
# # CHECK PALINDROME STRING

# %%
def my_palindrome(text: str) -> bool:
    if not isinstance(text,str):
        raise("Input must be a string")
    if text.strip() == "":
        raise TypeError ("Input text can not be empty")
    else:
        text = text.strip().lower()
    reversed_string = ""
    for char in text:
        reversed_string = char + reversed_string
    return text == reversed_string

if __name__ == "__main__":
    try:
        user_input = input("Enter your text to see if its a palindrome or not").strip().lower()
        if my_palindrome(user_input):
            print(f"{user_input} is a palindrome")
        else:
            print(f"{user_input} is not a palindrome")
    except(TypeError,ValueError) as e:
        print("Error : ",e)
# Out:
# Enter your text to see if its a palindrome or not umamu
# umamu is a palindrome
